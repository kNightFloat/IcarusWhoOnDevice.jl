# %%
using OMEinsum
using StaticArrays
using EtherArrays
using KernelAbstractions
using oneAPI

# %%
@kernel function ker!(data)
    idx::Int = @index(Global)
    a = E2SquareMatrix{2}(idx, 1, data)
    b = E2SquareMatrix{2}(idx, 5, data)
    c = similar(a)
    c .= a
    # a .= a * b
    # a .= ein"ik,kj->ij"(c, b)
    @ein a[i, j] := c[i, k] * b[k, j]
end

# %%
data_cpu = randn(Float32, 3, 8);
data_gpu = oneArray(data_cpu)
# Out:
# 3×8 oneArray{Float32, 2, oneAPI.oneL0.DeviceBuffer}:
#  -0.0678058  -0.442231   0.916985  …   0.306266   0.965054  -0.402869
#   1.0998      0.761035  -0.370254     -0.352635  -2.35477    0.349088
#  -0.534811   -0.607201   0.576879     -0.315892  -2.60085   -0.689827

# %%
ker!(oneAPIBackend(), 3)(data_gpu, ndrange=(3,))
KernelAbstractions.synchronize(oneAPIBackend())
# Out:
# InvalidIRError: compiling MethodInstance for gpu_ker!(::KernelAbstractions.CompilerMetadata{KernelAbstractions.NDIteration.DynamicSize, KernelAbstractions.NDIteration.DynamicCheck, Nothing, CartesianIndices{1, Tuple{Base.OneTo{Int64}}}, KernelAbstractions.NDIteration.NDRange{1, KernelAbstractions.NDIteration.DynamicSize, KernelAbstractions.NDIteration.StaticSize{(3,)}, CartesianIndices{1, Tuple{Base.OneTo{Int64}}}, Nothing}}, ::oneDeviceMatrix{Float32, 1}) resulted in invalid LLVM IR
#
# Reason: unsupported call to an unknown function (call to jl_alloc_genericmemory)
#
# Stacktrace:
#
#   [1] GenericMemory
#
#     @ ./boot.jl:516
#
#   [2] Array
#
#     @ ./boot.jl:578
#
#   [3] _array_for
#
#     @ ./array.jl:675
#
#   [4] _collect
#
#     @ ./array.jl:649
#
#   [5] collect
#
#     @ ./array.jl:647
#
#   [6] #7
#
#     @ ./none:0
#
#   [7] iterate
#
#     @ ./generator.jl:48
#
#   [8] collect
#
#     @ ./array.jl:791
#
#   [9] _tovec
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:95
#
#  [10] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:92
#
#  [11] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [12] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [13] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [14] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported call to an unknown function (call to jl_alloc_genericmemory)
#
# Stacktrace:
#
#   [1] GenericMemory
#
#     @ ./boot.jl:516
#
#   [2] Array
#
#     @ ./boot.jl:578
#
#   [3] _array_for
#
#     @ ./array.jl:675
#
#   [4] collect
#
#     @ ./array.jl:796
#
#   [5] _tovec
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:95
#
#   [6] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:92
#
#   [7] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#   [8] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#   [9] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [10] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported call to an unknown function (call to jl_alloc_genericmemory)
#
# Stacktrace:
#
#   [1] GenericMemory
#
#     @ ./boot.jl:516
#
#   [2] Array
#
#     @ ./boot.jl:578
#
#   [3] _array_for
#
#     @ ./array.jl:675
#
#   [4] _collect
#
#     @ ./array.jl:649
#
#   [5] collect
#
#     @ ./array.jl:647
#
#   [6] _tovec
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:95
#
#   [7] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:92
#
#   [8] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#   [9] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [10] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [11] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported call to an unknown function (call to jl_f__call_latest)
#
# Stacktrace:
#
#  [1] #invokelatest#2
#
#    @ ./essentials.jl:1055
#
#  [2] invokelatest
#
#    @ ./essentials.jl:1052
#
#  [3] macro expansion
#
#    @ ./logging/logging.jl:405
#
#  [4] DynamicEinCode
#
#    @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#  [5] EinCode
#
#    @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [6] macro expansion
#
#    @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [7] gpu_ker!
#
#    @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [8] gpu_ker!
#
#    @ ./none:0
#
# Reason: unsupported call to an unknown function (call to jl_f__call_latest)
#
# Stacktrace:
#
#  [1] #invokelatest#2
#
#    @ ./essentials.jl:1055
#
#  [2] invokelatest
#
#    @ ./essentials.jl:1052
#
#  [3] macro expansion
#
#    @ ./logging/logging.jl:353
#
#  [4] DynamicEinCode
#
#    @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#  [5] EinCode
#
#    @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [6] macro expansion
#
#    @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [7] gpu_ker!
#
#    @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [8] gpu_ker!
#
#    @ ./none:0
#
# Reason: unsupported call to an unknown function (call to jl_egal__unboxed)
#
# Stacktrace:
#
#  [1] ==
#
#    @ ./strings/string.jl:162
#
#  [2] !=
#
#    @ ./operators.jl:277
#
#  [3] fixup_stdlib_path
#
#    @ ./methodshow.jl:136
#
#  [4] macro expansion
#
#    @ ./logging/logging.jl:408
#
#  [5] DynamicEinCode
#
#    @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#  [6] EinCode
#
#    @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [7] macro expansion
#
#    @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [8] gpu_ker!
#
#    @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [9] gpu_ker!
#
#    @ ./none:0
#
# Reason: unsupported call to an unknown function (call to jl_egal__unboxed)
#
# Stacktrace:
#
#  [1] ==
#
#    @ ./strings/string.jl:162
#
#  [2] fixup_stdlib_path
#
#    @ ./methodshow.jl:140
#
#  [3] macro expansion
#
#    @ ./logging/logging.jl:408
#
#  [4] DynamicEinCode
#
#    @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#  [5] EinCode
#
#    @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [6] macro expansion
#
#    @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [7] gpu_ker!
#
#    @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [8] gpu_ker!
#
#    @ ./none:0
#
# Reason: unsupported call to an unknown function (call to ijl_copy_ast)
#
# Stacktrace:
#
#   [1] macro expansion
#
#     @ ./error.jl:234
#
#   [2] _nextind_continued
#
#     @ ./strings/string.jl:211
#
#   [3] _nextind_str
#
#     @ ./strings/string.jl:202
#
#   [4] nextind
#
#     @ ./strings/substring.jl:113
#
#   [5] startswith
#
#     @ ./strings/util.jl:75
#
#   [6] env_override_minlevel
#
#     @ ./logging/logging.jl:554
#
#   [7] current_logger_for_env
#
#     @ ./logging/logging.jl:339
#
#   [8] macro expansion
#
#     @ ./logging/logging.jl:400
#
#   [9] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#  [10] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [11] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [12] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [13] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported dynamic function invocation (call to string)
#
# Stacktrace:
#
#   [1] macro expansion
#
#     @ ./error.jl:235
#
#   [2] _nextind_continued
#
#     @ ./strings/string.jl:211
#
#   [3] _nextind_str
#
#     @ ./strings/string.jl:202
#
#   [4] nextind
#
#     @ ./strings/substring.jl:113
#
#   [5] startswith
#
#     @ ./strings/util.jl:75
#
#   [6] env_override_minlevel
#
#     @ ./logging/logging.jl:554
#
#   [7] current_logger_for_env
#
#     @ ./logging/logging.jl:339
#
#   [8] macro expansion
#
#     @ ./logging/logging.jl:400
#
#   [9] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#  [10] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [11] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [12] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [13] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported call to a lazy-initialized function (call to memcmp)
#
# Stacktrace:
#
#   [1] memcmp
#
#     @ ./cmem.jl:56
#
#   [2] _memcmp
#
#     @ ./strings/string.jl:152
#
#   [3] startswith
#
#     @ ./strings/util.jl:74
#
#   [4] env_override_minlevel
#
#     @ ./logging/logging.jl:554
#
#   [5] current_logger_for_env
#
#     @ ./logging/logging.jl:339
#
#   [6] macro expansion
#
#     @ ./logging/logging.jl:400
#
#   [7] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#   [8] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#   [9] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [10] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [11] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported call to an unknown function (call to julia.new_gc_frame)
#
# Stacktrace:
#
#  [1] _unlock
#
#    @ ./lock.jl:184
#
#  [2] unlock
#
#    @ ./lock.jl:178
#
#  [3] macro expansion
#
#    @ ./lock.jl:275
#
#  [4] is_root_module
#
#    @ ./loading.jl:2419
#
#  [5] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_gc_frame_slot)
#
# Stacktrace:
#
#  [1] _unlock
#
#    @ ./lock.jl:184
#
#  [2] unlock
#
#    @ ./lock.jl:178
#
#  [3] macro expansion
#
#    @ ./lock.jl:275
#
#  [4] is_root_module
#
#    @ ./loading.jl:2419
#
#  [5] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_pgcstack)
#
# Stacktrace:
#
#  [1] _unlock
#
#    @ ./lock.jl:184
#
#  [2] unlock
#
#    @ ./lock.jl:178
#
#  [3] macro expansion
#
#    @ ./lock.jl:275
#
#  [4] is_root_module
#
#    @ ./loading.jl:2419
#
#  [5] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.push_gc_frame)
#
# Stacktrace:
#
#  [1] _unlock
#
#    @ ./lock.jl:184
#
#  [2] unlock
#
#    @ ./lock.jl:178
#
#  [3] macro expansion
#
#    @ ./lock.jl:275
#
#  [4] is_root_module
#
#    @ ./loading.jl:2419
#
#  [5] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_excstack_state)
#
# Stacktrace:
#
#  [1] notifywaiters
#
#    @ ./lock.jl:187
#
#  [2] _unlock
#
#    @ ./lock.jl:184
#
#  [3] unlock
#
#    @ ./lock.jl:178
#
#  [4] macro expansion
#
#    @ ./lock.jl:275
#
#  [5] is_root_module
#
#    @ ./loading.jl:2419
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.except_enter)
#
# Stacktrace:
#
#  [1] notifywaiters
#
#    @ ./lock.jl:187
#
#  [2] _unlock
#
#    @ ./lock.jl:184
#
#  [3] unlock
#
#    @ ./lock.jl:178
#
#  [4] macro expansion
#
#    @ ./lock.jl:275
#
#  [5] is_root_module
#
#    @ ./loading.jl:2419
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to jl_gc_run_pending_finalizers)
#
# Stacktrace:
#
#  [1] enable_finalizers
#
#    @ ./gcutils.jl:161
#
#  [2] unlock
#
#    @ ./locks-mt.jl:68
#
#  [3] unlock
#
#    @ ./condition.jl:74
#
#  [4] notifywaiters
#
#    @ ./lock.jl:190
#
#  [5] _unlock
#
#    @ ./lock.jl:184
#
#  [6] unlock
#
#    @ ./lock.jl:178
#
#  [7] macro expansion
#
#    @ ./lock.jl:275
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler)
#
# Stacktrace:
#
#  [1] notifywaiters
#
#    @ ./lock.jl:187
#
#  [2] _unlock
#
#    @ ./lock.jl:184
#
#  [3] unlock
#
#    @ ./lock.jl:178
#
#  [4] macro expansion
#
#    @ ./lock.jl:275
#
#  [5] is_root_module
#
#    @ ./loading.jl:2419
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an external C function
#
# Stacktrace:
#
#  [1] enable_finalizers
#
#    @ ./gcutils.jl:160
#
#  [2] unlock
#
#    @ ./locks-mt.jl:68
#
#  [3] unlock
#
#    @ ./condition.jl:74
#
#  [4] notifywaiters
#
#    @ ./lock.jl:190
#
#  [5] _unlock
#
#    @ ./lock.jl:184
#
#  [6] unlock
#
#    @ ./lock.jl:178
#
#  [7] macro expansion
#
#    @ ./lock.jl:275
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.pop_gc_frame)
#
# Stacktrace:
#
#  [1] _unlock
#
#    @ ./lock.jl:184
#
#  [2] unlock
#
#    @ ./lock.jl:178
#
#  [3] macro expansion
#
#    @ ./lock.jl:275
#
#  [4] is_root_module
#
#    @ ./loading.jl:2419
#
#  [5] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported dynamic function invocation (call to notify(c::Base.GenericCondition, arg, all, error) @ Base condition.jl:149)
#
# Stacktrace:
#
#  [1] notify (repeats 2 times)
#
#    @ ./condition.jl:148
#
#  [2] notifywaiters
#
#    @ ./lock.jl:188
#
#  [3] _unlock
#
#    @ ./lock.jl:184
#
#  [4] unlock
#
#    @ ./lock.jl:178
#
#  [5] macro expansion
#
#    @ ./lock.jl:275
#
#  [6] is_root_module
#
#    @ ./loading.jl:2419
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler_noexcept)
#
# Stacktrace:
#
#  [1] notifywaiters
#
#    @ ./lock.jl:188
#
#  [2] _unlock
#
#    @ ./lock.jl:184
#
#  [3] unlock
#
#    @ ./lock.jl:178
#
#  [4] macro expansion
#
#    @ ./lock.jl:275
#
#  [5] is_root_module
#
#    @ ./loading.jl:2419
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.new_gc_frame)
#
# Stacktrace:
#
#  [1] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_gc_frame_slot)
#
# Stacktrace:
#
#  [1] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_pgcstack)
#
# Stacktrace:
#
#  [1] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.push_gc_frame)
#
# Stacktrace:
#
#  [1] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_excstack_state)
#
# Stacktrace:
#
#  [1] macro expansion
#
#    @ ./lock.jl:272
#
#  [2] is_root_module
#
#    @ ./loading.jl:2419
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.except_enter)
#
# Stacktrace:
#
#  [1] macro expansion
#
#    @ ./lock.jl:272
#
#  [2] is_root_module
#
#    @ ./loading.jl:2419
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler_noexcept)
#
# Stacktrace:
#
#  [1] macro expansion
#
#    @ ./lock.jl:273
#
#  [2] is_root_module
#
#    @ ./loading.jl:2419
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to jl_gc_run_pending_finalizers)
#
# Stacktrace:
#
#  [1] enable_finalizers
#
#    @ ./gcutils.jl:161
#
#  [2] unlock
#
#    @ ./lock.jl:178
#
#  [3] macro expansion
#
#    @ ./lock.jl:275
#
#  [4] is_root_module
#
#    @ ./loading.jl:2419
#
#  [5] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to ijl_eqtable_get)
#
# Stacktrace:
#
#  [1] get
#
#    @ ./iddict.jl:92
#
#  [2] in
#
#    @ ./iddict.jl:182
#
#  [3] haskey
#
#    @ ./abstractdict.jl:19
#
#  [4] macro expansion
#
#    @ ./lock.jl:273
#
#  [5] is_root_module
#
#    @ ./loading.jl:2419
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler)
#
# Stacktrace:
#
#  [1] macro expansion
#
#    @ ./lock.jl:272
#
#  [2] is_root_module
#
#    @ ./loading.jl:2419
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an external C function
#
# Stacktrace:
#
#  [1] enable_finalizers
#
#    @ ./gcutils.jl:160
#
#  [2] unlock
#
#    @ ./lock.jl:178
#
#  [3] macro expansion
#
#    @ ./lock.jl:275
#
#  [4] is_root_module
#
#    @ ./loading.jl:2419
#
#  [5] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.pop_gc_frame)
#
# Stacktrace:
#
#  [1] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_copy_ast)
#
# Stacktrace:
#
#  [1] macro expansion
#
#    @ ./error.jl:234
#
#  [2] _nextind_continued
#
#    @ ./strings/string.jl:211
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported dynamic function invocation (call to string)
#
# Stacktrace:
#
#  [1] macro expansion
#
#    @ ./error.jl:235
#
#  [2] _nextind_continued
#
#    @ ./strings/string.jl:211
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to memchr)
#
# Stacktrace:
#
#  [1] _search
#
#    @ ./strings/search.jl:50
#
#  [2] findnext
#
#    @ ./strings/search.jl:23
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to memchr)
#
# Stacktrace:
#
#  [1] _search
#
#    @ ./strings/search.jl:50
#
#  [2] findnext
#
#    @ ./strings/search.jl:25
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to memchr)
#
# Stacktrace:
#
#   [1] containsnul
#
#     @ ./strings/cstring.jl:78
#
#   [2] unsafe_convert
#
#     @ ./strings/cstring.jl:85
#
#   [3] _getenv
#
#     @ ./env.jl:55
#
#   [4] access_env
#
#     @ ./env.jl:59
#
#   [5] get
#
#     @ ./env.jl:165
#
#   [6] env_override_minlevel
#
#     @ ./logging/logging.jl:547
#
#   [7] current_logger_for_env
#
#     @ ./logging/logging.jl:339
#
#   [8] macro expansion
#
#     @ ./logging/logging.jl:400
#
#   [9] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#  [10] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [11] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [12] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [13] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported dynamic function invocation (call to var"#sprint#592"(context, sizehint::Integer, ::typeof(sprint), f::Function, args...) @ Base strings/io.jl:107)
#
# Stacktrace:
#
#   [1] sprint
#
#     @ ./strings/io.jl:107
#
#   [2] repr
#
#     @ ./strings/io.jl:286
#
#   [3] unsafe_convert
#
#     @ ./strings/cstring.jl:85
#
#   [4] _getenv
#
#     @ ./env.jl:55
#
#   [5] access_env
#
#     @ ./env.jl:59
#
#   [6] get
#
#     @ ./env.jl:165
#
#   [7] env_override_minlevel
#
#     @ ./logging/logging.jl:547
#
#   [8] current_logger_for_env
#
#     @ ./logging/logging.jl:339
#
#   [9] macro expansion
#
#     @ ./logging/logging.jl:400
#
#  [10] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#  [11] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [12] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [13] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [14] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported dynamic function invocation (call to _string(a::Union{Char, SubString{String}, String, Symbol}...) @ Base strings/substring.jl:240)
#
# Stacktrace:
#
#   [1] string
#
#     @ ./strings/substring.jl:236
#
#   [2] unsafe_convert
#
#     @ ./strings/cstring.jl:85
#
#   [3] _getenv
#
#     @ ./env.jl:55
#
#   [4] access_env
#
#     @ ./env.jl:59
#
#   [5] get
#
#     @ ./env.jl:165
#
#   [6] env_override_minlevel
#
#     @ ./logging/logging.jl:547
#
#   [7] current_logger_for_env
#
#     @ ./logging/logging.jl:339
#
#   [8] macro expansion
#
#     @ ./logging/logging.jl:400
#
#   [9] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#  [10] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [11] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [12] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [13] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported call to a lazy-initialized function (call to getenv)
#
# Stacktrace:
#
#   [1] _getenv
#
#     @ ./env.jl:55
#
#   [2] access_env
#
#     @ ./env.jl:59
#
#   [3] get
#
#     @ ./env.jl:165
#
#   [4] env_override_minlevel
#
#     @ ./logging/logging.jl:547
#
#   [5] current_logger_for_env
#
#     @ ./logging/logging.jl:339
#
#   [6] macro expansion
#
#     @ ./logging/logging.jl:400
#
#   [7] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#   [8] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#   [9] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [10] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [11] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported call to a lazy-initialized function (call to ijl_cstr_to_string)
#
# Stacktrace:
#
#   [1] unsafe_string
#
#     @ ./strings/string.jl:104
#
#   [2] unsafe_string
#
#     @ ./strings/cstring.jl:62
#
#   [3] access_env
#
#     @ ./env.jl:60
#
#   [4] get
#
#     @ ./env.jl:165
#
#   [5] env_override_minlevel
#
#     @ ./logging/logging.jl:547
#
#   [6] current_logger_for_env
#
#     @ ./logging/logging.jl:339
#
#   [7] macro expansion
#
#     @ ./logging/logging.jl:400
#
#   [8] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:88
#
#   [9] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [10] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [11] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [12] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported call to an unknown function (call to jl_alloc_genericmemory)
#
# Stacktrace:
#
#  [1] GenericMemory
#
#    @ ./boot.jl:516
#
#  [2] array_new_memory
#
#    @ ./array.jl:1058
#
#  [3] #133
#
#    @ ./array.jl:1129
#
#  [4] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to jl_genericmemory_copyto)
#
# Stacktrace:
#
#  [1] unsafe_copyto!
#
#    @ ./genericmemory.jl:125
#
#  [2] #133
#
#    @ ./array.jl:1133
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.new_gc_frame)
#
# Stacktrace:
#
#   [1] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [2] try_yieldto
#
#     @ ./task.jl:950
#
#   [3] wait
#
#     @ ./task.jl:1022
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_gc_frame_slot)
#
# Stacktrace:
#
#   [1] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [2] try_yieldto
#
#     @ ./task.jl:950
#
#   [3] wait
#
#     @ ./task.jl:1022
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_pgcstack)
#
# Stacktrace:
#
#   [1] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [2] try_yieldto
#
#     @ ./task.jl:950
#
#   [3] wait
#
#     @ ./task.jl:1022
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.push_gc_frame)
#
# Stacktrace:
#
#   [1] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [2] try_yieldto
#
#     @ ./task.jl:950
#
#   [3] wait
#
#     @ ./task.jl:1022
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_excstack_state)
#
# Stacktrace:
#
#   [1] pushfirst!
#
#     @ ./task.jl:731
#
#   [2] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [3] try_yieldto
#
#     @ ./task.jl:950
#
#   [4] wait
#
#     @ ./task.jl:1022
#
#   [5] #wait#731
#
#     @ ./condition.jl:130
#
#   [6] wait
#
#     @ ./condition.jl:125
#
#   [7] slowlock
#
#     @ ./lock.jl:157
#
#   [8] lock
#
#     @ ./lock.jl:147
#
#   [9] macro expansion
#
#     @ ./lock.jl:271
#
#  [10] is_root_module
#
#     @ ./loading.jl:2419
#
#  [11] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.except_enter)
#
# Stacktrace:
#
#   [1] pushfirst!
#
#     @ ./task.jl:731
#
#   [2] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [3] try_yieldto
#
#     @ ./task.jl:950
#
#   [4] wait
#
#     @ ./task.jl:1022
#
#   [5] #wait#731
#
#     @ ./condition.jl:130
#
#   [6] wait
#
#     @ ./condition.jl:125
#
#   [7] slowlock
#
#     @ ./lock.jl:157
#
#   [8] lock
#
#     @ ./lock.jl:147
#
#   [9] macro expansion
#
#     @ ./lock.jl:271
#
#  [10] is_root_module
#
#     @ ./loading.jl:2419
#
#  [11] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler_noexcept)
#
# Stacktrace:
#
#   [1] pushfirst!
#
#     @ ./task.jl:732
#
#   [2] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [3] try_yieldto
#
#     @ ./task.jl:950
#
#   [4] wait
#
#     @ ./task.jl:1022
#
#   [5] #wait#731
#
#     @ ./condition.jl:130
#
#   [6] wait
#
#     @ ./condition.jl:125
#
#   [7] slowlock
#
#     @ ./lock.jl:157
#
#   [8] lock
#
#     @ ./lock.jl:147
#
#   [9] macro expansion
#
#     @ ./lock.jl:271
#
#  [10] is_root_module
#
#     @ ./loading.jl:2419
#
#  [11] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to jl_gc_run_pending_finalizers)
#
# Stacktrace:
#
#   [1] enable_finalizers
#
#     @ ./gcutils.jl:161
#
#   [2] unlock
#
#     @ ./locks-mt.jl:68
#
#   [3] pushfirst!
#
#     @ ./task.jl:734
#
#   [4] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [5] try_yieldto
#
#     @ ./task.jl:950
#
#   [6] wait
#
#     @ ./task.jl:1022
#
#   [7] #wait#731
#
#     @ ./condition.jl:130
#
#   [8] wait
#
#     @ ./condition.jl:125
#
#   [9] slowlock
#
#     @ ./lock.jl:157
#
#  [10] lock
#
#     @ ./lock.jl:147
#
#  [11] macro expansion
#
#     @ ./lock.jl:271
#
#  [12] is_root_module
#
#     @ ./loading.jl:2419
#
#  [13] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.pop_gc_frame)
#
# Stacktrace:
#
#   [1] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [2] try_yieldto
#
#     @ ./task.jl:950
#
#   [3] wait
#
#     @ ./task.jl:1022
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler)
#
# Stacktrace:
#
#   [1] pushfirst!
#
#     @ ./task.jl:731
#
#   [2] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [3] try_yieldto
#
#     @ ./task.jl:950
#
#   [4] wait
#
#     @ ./task.jl:1022
#
#   [5] #wait#731
#
#     @ ./condition.jl:130
#
#   [6] wait
#
#     @ ./condition.jl:125
#
#   [7] slowlock
#
#     @ ./lock.jl:157
#
#   [8] lock
#
#     @ ./lock.jl:147
#
#   [9] macro expansion
#
#     @ ./lock.jl:271
#
#  [10] is_root_module
#
#     @ ./loading.jl:2419
#
#  [11] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an external C function
#
# Stacktrace:
#
#   [1] enable_finalizers
#
#     @ ./gcutils.jl:160
#
#   [2] unlock
#
#     @ ./locks-mt.jl:68
#
#   [3] pushfirst!
#
#     @ ./task.jl:734
#
#   [4] ensure_rescheduled
#
#     @ ./task.jl:981
#
#   [5] try_yieldto
#
#     @ ./task.jl:950
#
#   [6] wait
#
#     @ ./task.jl:1022
#
#   [7] #wait#731
#
#     @ ./condition.jl:130
#
#   [8] wait
#
#     @ ./condition.jl:125
#
#   [9] slowlock
#
#     @ ./lock.jl:157
#
#  [10] lock
#
#     @ ./lock.jl:147
#
#  [11] macro expansion
#
#     @ ./lock.jl:271
#
#  [12] is_root_module
#
#     @ ./loading.jl:2419
#
#  [13] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.new_gc_frame)
#
# Stacktrace:
#
#   [1] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [2] try_yieldto
#
#     @ ./task.jl:950
#
#   [3] wait
#
#     @ ./task.jl:1022
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_gc_frame_slot)
#
# Stacktrace:
#
#   [1] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [2] try_yieldto
#
#     @ ./task.jl:950
#
#   [3] wait
#
#     @ ./task.jl:1022
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_pgcstack)
#
# Stacktrace:
#
#   [1] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [2] try_yieldto
#
#     @ ./task.jl:950
#
#   [3] wait
#
#     @ ./task.jl:1022
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.push_gc_frame)
#
# Stacktrace:
#
#   [1] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [2] try_yieldto
#
#     @ ./task.jl:950
#
#   [3] wait
#
#     @ ./task.jl:1022
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_excstack_state)
#
# Stacktrace:
#
#   [1] list_deletefirst!
#
#     @ ./task.jl:756
#
#   [2] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [3] try_yieldto
#
#     @ ./task.jl:950
#
#   [4] wait
#
#     @ ./task.jl:1022
#
#   [5] #wait#731
#
#     @ ./condition.jl:130
#
#   [6] wait
#
#     @ ./condition.jl:125
#
#   [7] slowlock
#
#     @ ./lock.jl:157
#
#   [8] lock
#
#     @ ./lock.jl:147
#
#   [9] macro expansion
#
#     @ ./lock.jl:271
#
#  [10] is_root_module
#
#     @ ./loading.jl:2419
#
#  [11] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.except_enter)
#
# Stacktrace:
#
#   [1] list_deletefirst!
#
#     @ ./task.jl:756
#
#   [2] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [3] try_yieldto
#
#     @ ./task.jl:950
#
#   [4] wait
#
#     @ ./task.jl:1022
#
#   [5] #wait#731
#
#     @ ./condition.jl:130
#
#   [6] wait
#
#     @ ./condition.jl:125
#
#   [7] slowlock
#
#     @ ./lock.jl:157
#
#   [8] lock
#
#     @ ./lock.jl:147
#
#   [9] macro expansion
#
#     @ ./lock.jl:271
#
#  [10] is_root_module
#
#     @ ./loading.jl:2419
#
#  [11] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler_noexcept)
#
# Stacktrace:
#
#   [1] list_deletefirst!
#
#     @ ./task.jl:757
#
#   [2] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [3] try_yieldto
#
#     @ ./task.jl:950
#
#   [4] wait
#
#     @ ./task.jl:1022
#
#   [5] #wait#731
#
#     @ ./condition.jl:130
#
#   [6] wait
#
#     @ ./condition.jl:125
#
#   [7] slowlock
#
#     @ ./lock.jl:157
#
#   [8] lock
#
#     @ ./lock.jl:147
#
#   [9] macro expansion
#
#     @ ./lock.jl:271
#
#  [10] is_root_module
#
#     @ ./loading.jl:2419
#
#  [11] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to jl_gc_run_pending_finalizers)
#
# Stacktrace:
#
#   [1] enable_finalizers
#
#     @ ./gcutils.jl:161
#
#   [2] unlock
#
#     @ ./locks-mt.jl:68
#
#   [3] list_deletefirst!
#
#     @ ./task.jl:759
#
#   [4] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [5] try_yieldto
#
#     @ ./task.jl:950
#
#   [6] wait
#
#     @ ./task.jl:1022
#
#   [7] #wait#731
#
#     @ ./condition.jl:130
#
#   [8] wait
#
#     @ ./condition.jl:125
#
#   [9] slowlock
#
#     @ ./lock.jl:157
#
#  [10] lock
#
#     @ ./lock.jl:147
#
#  [11] macro expansion
#
#     @ ./lock.jl:271
#
#  [12] is_root_module
#
#     @ ./loading.jl:2419
#
#  [13] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.pop_gc_frame)
#
# Stacktrace:
#
#   [1] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [2] try_yieldto
#
#     @ ./task.jl:950
#
#   [3] wait
#
#     @ ./task.jl:1022
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler)
#
# Stacktrace:
#
#   [1] list_deletefirst!
#
#     @ ./task.jl:756
#
#   [2] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [3] try_yieldto
#
#     @ ./task.jl:950
#
#   [4] wait
#
#     @ ./task.jl:1022
#
#   [5] #wait#731
#
#     @ ./condition.jl:130
#
#   [6] wait
#
#     @ ./condition.jl:125
#
#   [7] slowlock
#
#     @ ./lock.jl:157
#
#   [8] lock
#
#     @ ./lock.jl:147
#
#   [9] macro expansion
#
#     @ ./lock.jl:271
#
#  [10] is_root_module
#
#     @ ./loading.jl:2419
#
#  [11] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an external C function
#
# Stacktrace:
#
#   [1] enable_finalizers
#
#     @ ./gcutils.jl:160
#
#   [2] unlock
#
#     @ ./locks-mt.jl:68
#
#   [3] list_deletefirst!
#
#     @ ./task.jl:759
#
#   [4] ensure_rescheduled
#
#     @ ./task.jl:986
#
#   [5] try_yieldto
#
#     @ ./task.jl:950
#
#   [6] wait
#
#     @ ./task.jl:1022
#
#   [7] #wait#731
#
#     @ ./condition.jl:130
#
#   [8] wait
#
#     @ ./condition.jl:125
#
#   [9] slowlock
#
#     @ ./lock.jl:157
#
#  [10] lock
#
#     @ ./lock.jl:147
#
#  [11] macro expansion
#
#     @ ./lock.jl:271
#
#  [12] is_root_module
#
#     @ ./loading.jl:2419
#
#  [13] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.new_gc_frame)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:950
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_pgcstack)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:950
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.push_gc_frame)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:950
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to ijl_get_task_tid)
#
# Stacktrace:
#
#   [1] threadid
#
#     @ ./task.jl:272
#
#   [2] ensure_rescheduled
#
#     @ ./task.jl:979
#
#   [3] try_yieldto
#
#     @ ./task.jl:950
#
#   [4] wait
#
#     @ ./task.jl:1022
#
#   [5] #wait#731
#
#     @ ./condition.jl:130
#
#   [6] wait
#
#     @ ./condition.jl:125
#
#   [7] slowlock
#
#     @ ./lock.jl:157
#
#   [8] lock
#
#     @ ./lock.jl:147
#
#   [9] macro expansion
#
#     @ ./lock.jl:271
#
#  [10] is_root_module
#
#     @ ./loading.jl:2419
#
#  [11] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_gc_frame_slot)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:950
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.pop_gc_frame)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:950
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_compile_8)
#
# Stacktrace:
#
#  [1] compile
#
#    @ ./pcre.jl:161
#
#  [2] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported dynamic function invocation (call to print_to_string(xs...) @ Base strings/io.jl:137)
#
# Stacktrace:
#
#  [1] string
#
#    @ ./strings/io.jl:189
#
#  [2] compile
#
#    @ ./pcre.jl:165
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.new_gc_frame)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./task.jl:1022
#
#  [2] #wait#731
#
#    @ ./condition.jl:130
#
#  [3] wait
#
#    @ ./condition.jl:125
#
#  [4] slowlock
#
#    @ ./lock.jl:157
#
#  [5] lock
#
#    @ ./lock.jl:147
#
#  [6] macro expansion
#
#    @ ./lock.jl:271
#
#  [7] is_root_module
#
#    @ ./loading.jl:2419
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_pgcstack)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./task.jl:1022
#
#  [2] #wait#731
#
#    @ ./condition.jl:130
#
#  [3] wait
#
#    @ ./condition.jl:125
#
#  [4] slowlock
#
#    @ ./lock.jl:157
#
#  [5] lock
#
#    @ ./lock.jl:147
#
#  [6] macro expansion
#
#    @ ./lock.jl:271
#
#  [7] is_root_module
#
#    @ ./loading.jl:2419
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.push_gc_frame)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./task.jl:1022
#
#  [2] #wait#731
#
#    @ ./condition.jl:130
#
#  [3] wait
#
#    @ ./condition.jl:125
#
#  [4] slowlock
#
#    @ ./lock.jl:157
#
#  [5] lock
#
#    @ ./lock.jl:147
#
#  [6] macro expansion
#
#    @ ./lock.jl:271
#
#  [7] is_root_module
#
#    @ ./loading.jl:2419
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_excstack_state)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:947
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.except_enter)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:947
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.pop_gc_frame)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./task.jl:1022
#
#  [2] #wait#731
#
#    @ ./condition.jl:130
#
#  [3] wait
#
#    @ ./condition.jl:125
#
#  [4] slowlock
#
#    @ ./lock.jl:157
#
#  [5] lock
#
#    @ ./lock.jl:147
#
#  [6] macro expansion
#
#    @ ./lock.jl:271
#
#  [7] is_root_module
#
#    @ ./loading.jl:2419
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to ijl_switch)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:948
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler_noexcept)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:948
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:947
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to ijl_get_next_task)
#
# Stacktrace:
#
#  [1] try_yieldto
#
#    @ ./task.jl:950
#
#  [2] wait
#
#    @ ./task.jl:1022
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_gc_frame_slot)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./task.jl:1022
#
#  [2] #wait#731
#
#    @ ./condition.jl:130
#
#  [3] wait
#
#    @ ./condition.jl:125
#
#  [4] slowlock
#
#    @ ./lock.jl:157
#
#  [5] lock
#
#    @ ./lock.jl:147
#
#  [6] macro expansion
#
#    @ ./lock.jl:271
#
#  [7] is_root_module
#
#    @ ./loading.jl:2419
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.new_gc_frame)
#
# Stacktrace:
#
#  [1] #wait#731
#
#    @ ./condition.jl:130
#
#  [2] wait
#
#    @ ./condition.jl:125
#
#  [3] slowlock
#
#    @ ./lock.jl:157
#
#  [4] lock
#
#    @ ./lock.jl:147
#
#  [5] macro expansion
#
#    @ ./lock.jl:271
#
#  [6] is_root_module
#
#    @ ./loading.jl:2419
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_pgcstack)
#
# Stacktrace:
#
#  [1] #wait#731
#
#    @ ./condition.jl:130
#
#  [2] wait
#
#    @ ./condition.jl:125
#
#  [3] slowlock
#
#    @ ./lock.jl:157
#
#  [4] lock
#
#    @ ./lock.jl:147
#
#  [5] macro expansion
#
#    @ ./lock.jl:271
#
#  [6] is_root_module
#
#    @ ./loading.jl:2419
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.push_gc_frame)
#
# Stacktrace:
#
#  [1] #wait#731
#
#    @ ./condition.jl:130
#
#  [2] wait
#
#    @ ./condition.jl:125
#
#  [3] slowlock
#
#    @ ./lock.jl:157
#
#  [4] lock
#
#    @ ./lock.jl:147
#
#  [5] macro expansion
#
#    @ ./lock.jl:271
#
#  [6] is_root_module
#
#    @ ./loading.jl:2419
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.safepoint)
#
# Stacktrace:
#
#  [1] safepoint
#
#    @ ./gcutils.jl:255
#
#  [2] wait
#
#    @ ./task.jl:1019
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_gc_frame_slot)
#
# Stacktrace:
#
#  [1] #wait#731
#
#    @ ./condition.jl:130
#
#  [2] wait
#
#    @ ./condition.jl:125
#
#  [3] slowlock
#
#    @ ./lock.jl:157
#
#  [4] lock
#
#    @ ./lock.jl:147
#
#  [5] macro expansion
#
#    @ ./lock.jl:271
#
#  [6] is_root_module
#
#    @ ./loading.jl:2419
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to ijl_process_events)
#
# Stacktrace:
#
#  [1] process_events
#
#    @ ./libuv.jl:125
#
#  [2] wait
#
#    @ ./task.jl:1023
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.pop_gc_frame)
#
# Stacktrace:
#
#  [1] #wait#731
#
#    @ ./condition.jl:130
#
#  [2] wait
#
#    @ ./condition.jl:125
#
#  [3] slowlock
#
#    @ ./lock.jl:157
#
#  [4] lock
#
#    @ ./lock.jl:147
#
#  [5] macro expansion
#
#    @ ./lock.jl:271
#
#  [6] is_root_module
#
#    @ ./loading.jl:2419
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.new_gc_frame)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./condition.jl:125
#
#  [2] slowlock
#
#    @ ./lock.jl:157
#
#  [3] lock
#
#    @ ./lock.jl:147
#
#  [4] macro expansion
#
#    @ ./lock.jl:271
#
#  [5] is_root_module
#
#    @ ./loading.jl:2419
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_gc_frame_slot)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./condition.jl:125
#
#  [2] slowlock
#
#    @ ./lock.jl:157
#
#  [3] lock
#
#    @ ./lock.jl:147
#
#  [4] macro expansion
#
#    @ ./lock.jl:271
#
#  [5] is_root_module
#
#    @ ./loading.jl:2419
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_pgcstack)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./condition.jl:125
#
#  [2] slowlock
#
#    @ ./lock.jl:157
#
#  [3] lock
#
#    @ ./lock.jl:147
#
#  [4] macro expansion
#
#    @ ./lock.jl:271
#
#  [5] is_root_module
#
#    @ ./loading.jl:2419
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.push_gc_frame)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./condition.jl:125
#
#  [2] slowlock
#
#    @ ./lock.jl:157
#
#  [3] lock
#
#    @ ./lock.jl:147
#
#  [4] macro expansion
#
#    @ ./lock.jl:271
#
#  [5] is_root_module
#
#    @ ./loading.jl:2419
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to jl_gc_run_pending_finalizers)
#
# Stacktrace:
#
#   [1] enable_finalizers
#
#     @ ./gcutils.jl:161
#
#   [2] unlock
#
#     @ ./locks-mt.jl:68
#
#   [3] unlockall
#
#     @ ./condition.jl:23
#
#   [4] #wait#731
#
#     @ ./condition.jl:128
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_excstack_state)
#
# Stacktrace:
#
#  [1] #wait#731
#
#    @ ./condition.jl:129
#
#  [2] wait
#
#    @ ./condition.jl:125
#
#  [3] slowlock
#
#    @ ./lock.jl:157
#
#  [4] lock
#
#    @ ./lock.jl:147
#
#  [5] macro expansion
#
#    @ ./lock.jl:271
#
#  [6] is_root_module
#
#    @ ./loading.jl:2419
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.except_enter)
#
# Stacktrace:
#
#  [1] #wait#731
#
#    @ ./condition.jl:129
#
#  [2] wait
#
#    @ ./condition.jl:125
#
#  [3] slowlock
#
#    @ ./lock.jl:157
#
#  [4] lock
#
#    @ ./lock.jl:147
#
#  [5] macro expansion
#
#    @ ./lock.jl:271
#
#  [6] is_root_module
#
#    @ ./loading.jl:2419
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler)
#
# Stacktrace:
#
#  [1] #wait#731
#
#    @ ./condition.jl:129
#
#  [2] wait
#
#    @ ./condition.jl:125
#
#  [3] slowlock
#
#    @ ./lock.jl:157
#
#  [4] lock
#
#    @ ./lock.jl:147
#
#  [5] macro expansion
#
#    @ ./lock.jl:271
#
#  [6] is_root_module
#
#    @ ./loading.jl:2419
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an external C function
#
# Stacktrace:
#
#   [1] enable_finalizers
#
#     @ ./gcutils.jl:160
#
#   [2] unlock
#
#     @ ./locks-mt.jl:68
#
#   [3] unlockall
#
#     @ ./condition.jl:23
#
#   [4] #wait#731
#
#     @ ./condition.jl:128
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler_noexcept)
#
# Stacktrace:
#
#  [1] #wait#731
#
#    @ ./condition.jl:130
#
#  [2] wait
#
#    @ ./condition.jl:125
#
#  [3] slowlock
#
#    @ ./lock.jl:157
#
#  [4] lock
#
#    @ ./lock.jl:147
#
#  [5] macro expansion
#
#    @ ./lock.jl:271
#
#  [6] is_root_module
#
#    @ ./loading.jl:2419
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.pop_gc_frame)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./condition.jl:125
#
#  [2] slowlock
#
#    @ ./lock.jl:157
#
#  [3] lock
#
#    @ ./lock.jl:147
#
#  [4] macro expansion
#
#    @ ./lock.jl:271
#
#  [5] is_root_module
#
#    @ ./loading.jl:2419
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.new_gc_frame)
#
# Stacktrace:
#
#  [1] lock
#
#    @ ./lock.jl:147
#
#  [2] macro expansion
#
#    @ ./lock.jl:271
#
#  [3] is_root_module
#
#    @ ./loading.jl:2419
#
#  [4] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_gc_frame_slot)
#
# Stacktrace:
#
#  [1] lock
#
#    @ ./lock.jl:147
#
#  [2] macro expansion
#
#    @ ./lock.jl:271
#
#  [3] is_root_module
#
#    @ ./loading.jl:2419
#
#  [4] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_pgcstack)
#
# Stacktrace:
#
#  [1] lock
#
#    @ ./lock.jl:147
#
#  [2] macro expansion
#
#    @ ./lock.jl:271
#
#  [3] is_root_module
#
#    @ ./loading.jl:2419
#
#  [4] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.push_gc_frame)
#
# Stacktrace:
#
#  [1] lock
#
#    @ ./lock.jl:147
#
#  [2] macro expansion
#
#    @ ./lock.jl:271
#
#  [3] is_root_module
#
#    @ ./loading.jl:2419
#
#  [4] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_excstack_state)
#
# Stacktrace:
#
#  [1] slowlock
#
#    @ ./lock.jl:151
#
#  [2] lock
#
# ...
#
#    @ ./array.jl:537
#
#  [5] fill
#
#    @ ./array.jl:535
#
#  [6] get_local_match_context
#
#    @ ./pcre.jl:44
#
#  [7] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler_noexcept)
#
# Stacktrace:
#
#  [1] get_local_match_context
#
#    @ ./pcre.jl:44
#
#  [2] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to jl_gc_run_pending_finalizers)
#
# Stacktrace:
#
#  [1] enable_finalizers
#
#    @ ./gcutils.jl:161
#
#  [2] unlock
#
#    @ ./locks-mt.jl:68
#
#  [3] get_local_match_context
#
#    @ ./pcre.jl:47
#
#  [4] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_jit_stack_create_8)
#
# Stacktrace:
#
#  [1] create_match_context
#
#    @ ./pcre.jl:17
#
#  [2] get_local_match_context
#
#    @ ./pcre.jl:53
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_match_context_create_8)
#
# Stacktrace:
#
#  [1] create_match_context
#
#    @ ./pcre.jl:20
#
#  [2] get_local_match_context
#
#    @ ./pcre.jl:53
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_jit_stack_assign_8)
#
# Stacktrace:
#
#  [1] create_match_context
#
#    @ ./pcre.jl:22
#
#  [2] get_local_match_context
#
#    @ ./pcre.jl:53
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_excstack_state)
#
# Stacktrace:
#
#  [1] get_local_match_context
#
#    @ ./pcre.jl:41
#
#  [2] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.except_enter)
#
# Stacktrace:
#
#  [1] get_local_match_context
#
#    @ ./pcre.jl:41
#
#  [2] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to ijl_pop_handler)
#
# Stacktrace:
#
#  [1] get_local_match_context
#
#    @ ./pcre.jl:41
#
#  [2] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an external C function
#
# Stacktrace:
#
#  [1] _mth
#
#    @ ./pcre.jl:32
#
#  [2] get_local_match_context
#
#    @ ./pcre.jl:44
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an external C function
#
# Stacktrace:
#
#  [1] enable_finalizers
#
#    @ ./gcutils.jl:160
#
#  [2] unlock
#
#    @ ./locks-mt.jl:68
#
#  [3] get_local_match_context
#
#    @ ./pcre.jl:47
#
#  [4] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_match_data_create_from_pattern_8)
#
# Stacktrace:
#
#  [1] create_match_data
#
#    @ ./pcre.jl:227
#
#  [2] exec_r
#
#    @ ./pcre.jl:214
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_match_8)
#
# Stacktrace:
#
#  [1] _exec
#
#    @ ./pcre.jl:205
#
#  [2] exec
#
#    @ ./pcre.jl:199
#
#  [3] exec_r
#
#    @ ./pcre.jl:215
#
#  [4] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported dynamic function invocation (call to _string(a::Union{Char, SubString{String}, String, Symbol}...) @ Base strings/substring.jl:240)
#
# Stacktrace:
#
#  [1] string
#
#    @ ./strings/substring.jl:236
#
#  [2] _exec
#
#    @ ./pcre.jl:209
#
#  [3] exec
#
#    @ ./pcre.jl:199
#
#  [4] exec_r
#
#    @ ./pcre.jl:215
#
#  [5] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_match_data_free_8)
#
# Stacktrace:
#
#  [1] free_match_data
#
#    @ ./pcre.jl:178
#
#  [2] exec_r
#
#    @ ./pcre.jl:216
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to jl_alloc_genericmemory)
#
# Stacktrace:
#
#   [1] GenericMemory
#
#     @ ./boot.jl:516
#
#   [2] Array
#
#     @ ./boot.jl:578
#
#   [3] _array_for
#
#     @ ./array.jl:675
#
#   [4] _collect
#
#     @ ./array.jl:649
#
#   [5] collect
#
#     @ ./array.jl:647
#
#   [6] #7
#
#     @ ./none:0
#
#   [7] iterate
#
#     @ ./generator.jl:48
#
#   [8] collect_to!
#
#     @ ./array.jl:849
#
#   [9] collect_to_with_first!
#
#     @ ./array.jl:827
#
#  [10] collect
#
#     @ ./array.jl:801
#
#  [11] _tovec
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:95
#
#  [12] DynamicEinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:92
#
#  [13] EinCode
#
#     @ ~/.julia/packages/OMEinsum/6mSzJ/src/Core.jl:104
#
#  [14] macro expansion
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [15] gpu_ker!
#
#     @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [16] gpu_ker!
#
#     @ ./none:0
#
# Reason: unsupported call to a lazy-initialized function (call to jl_genericmemory_copyto)
#
# Stacktrace:
#
#  [1] unsafe_copyto!
#
#    @ ./genericmemory.jl:125
#
#  [2] unsafe_copyto!
#
#    @ ./array.jl:284
#
#  [3] _deleteat!
#
#    @ ./array.jl:1220
#
#  [4] deleteat!
#
#    @ ./array.jl:1784
#
#  [5] normpath
#
#    @ ./path.jl:400
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to jl_genericmemory_copyto)
#
# Stacktrace:
#
#  [1] unsafe_copyto!
#
#    @ ./genericmemory.jl:125
#
#  [2] unsafe_copyto!
#
#    @ ./array.jl:284
#
#  [3] _deleteat!
#
#    @ ./array.jl:1223
#
#  [4] deleteat!
#
#    @ ./array.jl:1784
#
#  [5] normpath
#
#    @ ./path.jl:400
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_match_data_create_from_pattern_8)
#
# Stacktrace:
#
#  [1] create_match_data
#
#    @ ./pcre.jl:227
#
#  [2] exec_r_data
#
#    @ ./pcre.jl:221
#
#  [3] _findnext_re
#
#    @ ./regex.jl:479
#
#  [4] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_match_8)
#
# Stacktrace:
#
#  [1] _exec
#
#    @ ./pcre.jl:205
#
#  [2] exec
#
#    @ ./pcre.jl:199
#
#  [3] exec_r_data
#
#    @ ./pcre.jl:222
#
#  [4] _findnext_re
#
#    @ ./regex.jl:479
#
#  [5] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported dynamic function invocation (call to _string(a::Union{Char, SubString{String}, String, Symbol}...) @ Base strings/substring.jl:240)
#
# Stacktrace:
#
#  [1] string
#
#    @ ./strings/substring.jl:236
#
#  [2] _exec
#
#    @ ./pcre.jl:209
#
#  [3] exec
#
#    @ ./pcre.jl:199
#
#  [4] exec_r_data
#
#    @ ./pcre.jl:222
#
#  [5] _findnext_re
#
#    @ ./regex.jl:479
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to ijl_rethrow)
#
# Stacktrace:
#
#  [1] rethrow
#
#    @ ./error.jl:61
#
#  [2] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an external C function
#
# Stacktrace:
#
#   [1] trypoptask
#
#     @ ./task.jl:998
#
#   [2] poptask
#
#     @ ./task.jl:1010
#
#   [3] wait
#
#     @ ./task.jl:1021
#
#   [4] #wait#731
#
#     @ ./condition.jl:130
#
#   [5] wait
#
#     @ ./condition.jl:125
#
#   [6] slowlock
#
#     @ ./lock.jl:157
#
#   [7] lock
#
#     @ ./lock.jl:147
#
#   [8] macro expansion
#
#     @ ./lock.jl:271
#
#   [9] is_root_module
#
#     @ ./loading.jl:2419
#
#  [10] multiple call sites
#
#     @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.new_gc_frame)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./task.jl:1021
#
#  [2] #wait#731
#
#    @ ./condition.jl:130
#
#  [3] wait
#
#    @ ./condition.jl:125
#
#  [4] slowlock
#
#    @ ./lock.jl:157
#
#  [5] lock
#
#    @ ./lock.jl:147
#
#  [6] macro expansion
#
#    @ ./lock.jl:271
#
#  [7] is_root_module
#
#    @ ./loading.jl:2419
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_pgcstack)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./task.jl:1021
#
#  [2] #wait#731
#
#    @ ./condition.jl:130
#
#  [3] wait
#
#    @ ./condition.jl:125
#
#  [4] slowlock
#
#    @ ./lock.jl:157
#
#  [5] lock
#
#    @ ./lock.jl:147
#
#  [6] macro expansion
#
#    @ ./lock.jl:271
#
#  [7] is_root_module
#
#    @ ./loading.jl:2419
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.push_gc_frame)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./task.jl:1021
#
#  [2] #wait#731
#
#    @ ./condition.jl:130
#
#  [3] wait
#
#    @ ./condition.jl:125
#
#  [4] slowlock
#
#    @ ./lock.jl:157
#
#  [5] lock
#
#    @ ./lock.jl:147
#
#  [6] macro expansion
#
#    @ ./lock.jl:271
#
#  [7] is_root_module
#
#    @ ./loading.jl:2419
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.pop_gc_frame)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./task.jl:1021
#
#  [2] #wait#731
#
#    @ ./condition.jl:130
#
#  [3] wait
#
#    @ ./condition.jl:125
#
#  [4] slowlock
#
#    @ ./lock.jl:157
#
#  [5] lock
#
#    @ ./lock.jl:147
#
#  [6] macro expansion
#
#    @ ./lock.jl:271
#
#  [7] is_root_module
#
#    @ ./loading.jl:2419
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to ijl_task_get_next)
#
# Stacktrace:
#
#  [1] poptask
#
#    @ ./task.jl:1012
#
#  [2] wait
#
#    @ ./task.jl:1021
#
#  [3] #wait#731
#
#    @ ./condition.jl:130
#
#  [4] wait
#
#    @ ./condition.jl:125
#
#  [5] slowlock
#
#    @ ./lock.jl:157
#
#  [6] lock
#
#    @ ./lock.jl:147
#
#  [7] macro expansion
#
#    @ ./lock.jl:271
#
#  [8] is_root_module
#
#    @ ./loading.jl:2419
#
#  [9] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to julia.get_gc_frame_slot)
#
# Stacktrace:
#
#  [1] wait
#
#    @ ./task.jl:1021
#
#  [2] #wait#731
#
#    @ ./condition.jl:130
#
#  [3] wait
#
#    @ ./condition.jl:125
#
#  [4] slowlock
#
#    @ ./lock.jl:157
#
#  [5] lock
#
#    @ ./lock.jl:147
#
#  [6] macro expansion
#
#    @ ./lock.jl:271
#
#  [7] is_root_module
#
#    @ ./loading.jl:2419
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_match_8)
#
# Stacktrace:
#
#  [1] _exec
#
#    @ ./pcre.jl:205
#
#  [2] exec
#
#    @ ./pcre.jl:199
#
#  [3] _findnext_re
#
#    @ ./regex.jl:481
#
#  [4] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported dynamic function invocation (call to _string(a::Union{Char, SubString{String}, String, Symbol}...) @ Base strings/substring.jl:240)
#
# Stacktrace:
#
#  [1] string
#
#    @ ./strings/substring.jl:236
#
#  [2] _exec
#
#    @ ./pcre.jl:209
#
#  [3] exec
#
#    @ ./pcre.jl:199
#
#  [4] _findnext_re
#
#    @ ./regex.jl:481
#
#  [5] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_get_ovector_pointer_8)
#
# Stacktrace:
#
#  [1] ovec_ptr
#
#    @ ./pcre.jl:150
#
#  [2] _findnext_re
#
#    @ ./regex.jl:485
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to a lazy-initialized function (call to pcre2_match_data_free_8)
#
# Stacktrace:
#
#  [1] free_match_data
#
#    @ ./pcre.jl:178
#
#  [2] _findnext_re
#
#    @ ./regex.jl:490
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an external C function
#
# Reason: unsupported call to an unknown function (call to gpu_malloc)
#
# Stacktrace:
#
#  [1] malloc
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:85
#
#  [2] macro expansion
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:180
#
#  [3] macro expansion
#
#    @ ./none:0
#
#  [4] box
#
#    @ ./none:0
#
#  [5] box_int32
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:209
#
#  [6] string
#
#    @ ./strings/io.jl:189
#
#  [7] err_message
#
#    @ ./pcre.jl:194
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to gpu_malloc)
#
# Stacktrace:
#
#  [1] malloc
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:85
#
#  [2] gc_pool_alloc
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:116
#
#  [3] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to gpu_malloc)
#
# Stacktrace:
#
#  [1] malloc
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:85
#
#  [2] macro expansion
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:180
#
#  [3] macro expansion
#
#    @ ./none:0
#
#  [4] box
#
#    @ ./none:0
#
#  [5] box_int64
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:209
#
#  [6] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported call to an unknown function (call to gpu_malloc)
#
# Stacktrace:
#
#  [1] malloc
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:85
#
#  [2] macro expansion
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:180
#
#  [3] macro expansion
#
#    @ ./none:0
#
#  [4] box
#
#    @ ./none:0
#
#  [5] box_uint64
#
#    @ ~/.julia/packages/GPUCompiler/j4HFa/src/runtime.jl:209
#
#  [6] string
#
#    @ ./strings/io.jl:189
#
#  [7] compile
#
#    @ ./pcre.jl:165
#
#  [8] multiple call sites
#
#    @ unknown:0
#
# Reason: unsupported dynamic function invocation (call to einsum(code::AbstractEinsum, xs::Tuple) @ OMEinsum ~/.julia/packages/OMEinsum/6mSzJ/src/einsum.jl:24)
#
# Stacktrace:
#
#  [1] macro expansion
#
#    @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W3sZmlsZQ==.jl:9
#
#  [2] gpu_ker!
#
#    @ ~/.julia/packages/KernelAbstractions/X5fk1/src/macros.jl:332
#
#  [3] gpu_ker!
#
#    @ ./none:0
#
# Hint: catch this exception as `err` and call `code_typed(err; interactive = true)` to introspect the erroneous code with Cthulhu.jl
#
#
#
# Stacktrace:
#
#   [1] check_ir(job::GPUCompiler.CompilerJob{GPUCompiler.SPIRVCompilerTarget, oneAPI.oneAPICompilerParams}, args::LLVM.Module)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/j4HFa/src/validation.jl:167
#
#   [2] macro expansion
#
#     @ ~/.julia/packages/GPUCompiler/j4HFa/src/driver.jl:417 [inlined]
#
#   [3] emit_llvm(job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/j4HFa/src/utils.jl:116
#
#   [4] emit_llvm(job::GPUCompiler.CompilerJob)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/j4HFa/src/utils.jl:114
#
#   [5] compile_unhooked(output::Symbol, job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/j4HFa/src/driver.jl:95
#
#   [6] compile_unhooked
#
#     @ ~/.julia/packages/GPUCompiler/j4HFa/src/driver.jl:80 [inlined]
#
#   [7] compile(target::Symbol, job::GPUCompiler.CompilerJob; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/j4HFa/src/driver.jl:67
#
#   [8] compile
#
#     @ ~/.julia/packages/GPUCompiler/j4HFa/src/driver.jl:55 [inlined]
#
#   [9] #37
#
#     @ ~/.julia/packages/oneAPI/CNvkW/src/compiler/compilation.jl:81 [inlined]
#
#  [10] JuliaContext(f::oneAPI.var"#37#38"{GPUCompiler.CompilerJob{GPUCompiler.SPIRVCompilerTarget, oneAPI.oneAPICompilerParams}}; kwargs::@Kwargs{})
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/j4HFa/src/driver.jl:34
#
#  [11] JuliaContext(f::Function)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/j4HFa/src/driver.jl:25
#
#  [12] compile(job::GPUCompiler.CompilerJob)
#
#     @ oneAPI ~/.julia/packages/oneAPI/CNvkW/src/compiler/compilation.jl:80
#
#  [13] actual_compilation(cache::Dict{Any, Any}, src::Core.MethodInstance, world::UInt64, cfg::GPUCompiler.CompilerConfig{GPUCompiler.SPIRVCompilerTarget, oneAPI.oneAPICompilerParams}, compiler::typeof(oneAPI.compile), linker::typeof(oneAPI.link))
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/j4HFa/src/execution.jl:245
#
#  [14] cached_compilation(cache::Dict{Any, Any}, src::Core.MethodInstance, cfg::GPUCompiler.CompilerConfig{GPUCompiler.SPIRVCompilerTarget, oneAPI.oneAPICompilerParams}, compiler::Function, linker::Function)
#
#     @ GPUCompiler ~/.julia/packages/GPUCompiler/j4HFa/src/execution.jl:159
#
#  [15] macro expansion
#
#     @ ~/.julia/packages/oneAPI/CNvkW/src/compiler/execution.jl:203 [inlined]
#
#  [16] macro expansion
#
#     @ ./lock.jl:273 [inlined]
#
#  [17] zefunction(f::typeof(gpu_ker!), tt::Type{Tuple{KernelAbstractions.CompilerMetadata{KernelAbstractions.NDIteration.DynamicSize, KernelAbstractions.NDIteration.DynamicCheck, Nothing, CartesianIndices{1, Tuple{Base.OneTo{Int64}}}, KernelAbstractions.NDIteration.NDRange{1, KernelAbstractions.NDIteration.DynamicSize, KernelAbstractions.NDIteration.StaticSize{(3,)}, CartesianIndices{1, Tuple{Base.OneTo{Int64}}}, Nothing}}, oneDeviceMatrix{Float32, 1}}}; kwargs::@Kwargs{})
#
#     @ oneAPI ~/.julia/packages/oneAPI/CNvkW/src/compiler/execution.jl:198
#
#  [18] zefunction
#
#     @ ~/.julia/packages/oneAPI/CNvkW/src/compiler/execution.jl:195 [inlined]
#
#  [19] macro expansion
#
#     @ ~/.julia/packages/oneAPI/CNvkW/src/compiler/execution.jl:66 [inlined]
#
#  [20] (::KernelAbstractions.Kernel{oneAPIBackend, KernelAbstractions.NDIteration.StaticSize{(3,)}, KernelAbstractions.NDIteration.DynamicSize, typeof(gpu_ker!)})(args::oneArray{Float32, 2, oneAPI.oneL0.DeviceBuffer}; ndrange::Tuple{Int64}, workgroupsize::Nothing)
#
#     @ oneAPI.oneAPIKernels ~/.julia/packages/oneAPI/CNvkW/src/oneAPIKernels.jl:89
#
#  [21] top-level scope
#
#     @ ~/Apollo/kNightFloat/IcarusWhoOnDevice.jl/test_OMEinsum/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:1
